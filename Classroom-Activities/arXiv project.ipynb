# %%
    import urllib
    url = 'http://export.arxiv.org/api/query?search_query=all:electron&start=0&max_results=1'
    data = urllib.urlopen(url).read()
    print data

# %%
import urllib.request as libreq
with libreq.urlopen('http://export.arxiv.org/api/query?search_query=all:electron&start=0&max_results=1') as url:
    r = url.read()
print(r)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<feed xmlns="http://www.w3.org/2005/Atom">\n  <link href="http://arxiv.org/api/query?search_query%3Dall%3Aelectron%26id_list%3D%26start%3D0%26max_results%3D1" rel="self" type="application/atom+xml"/>\n  <title type="html">ArXiv Query: search_query=all:electron&amp;id_list=&amp;start=0&amp;max_results=1</title>\n  <id>http://arxiv.org/api/cHxbiOdZaP56ODnBPIenZhzg5f8</id>\n  <updated>2019-09-12T00:00:00-04:00</updated>\n  <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">149081</opensearch:totalResults>\n  <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>\n  <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">1</opensearch:itemsPerPage>\n  <entry>\n    <id>http://arxiv.org/abs/cond-mat/0102536v1</id>\n    <updated>2001-02-28T20:12:09Z</updated>\n    <published>2001-02-28T20:12:09Z</published>\n    <title>Impact of Electron-Electron
# ...

# %%
import feedparser

# %%
url = 'http://export.arxiv.org/api/query?search_query=ti:%22single+molecule+microscopy%22&start=0&max_results=10'

# %%
tree = feedparser.parse(url)

# %%
tree
# Out:
# {'feed': {'links': [{'href': 'http://arxiv.org/api/query?search_query%3Dti%3A%22single%20molecule%20microscopy%22%26id_list%3D%26start%3D0%26max_results%3D10',
#     'rel': 'self',
#     'type': 'application/atom+xml'}],
#   'title': 'ArXiv Query: search_query=ti:"single molecule microscopy"&id_list=&start=0&max_results=10',
#   'title_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://export.arxiv.org/api/query?search_query=ti:%22single+molecule+microscopy%22&start=0&max_results=10',
#    'value': 'ArXiv Query: search_query=ti:"single molecule microscopy"&id_list=&start=0&max_results=10'},
#   'id': 'http://arxiv.org/api/6AEcvY2vThjES1La0YL13e3y/Xo',
#   'guidislink': True,
#   'link': 'http://arxiv.org/api/6AEcvY2vThjES1La0YL13e3y/Xo',
#   'updated': '2019-09-12T00:00:00-04:00',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=12, tm_hour=4, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=255, tm_isdst=0),
#   'opensearch_totalresults': '4',
# ...

# %%
import pandas as pd
result = {"Author":[], "Title":[], "Abstract":[], "DoI":[]}
results_df = pd.DataFrame.from_dict(tree.entries)
results_df
# Out:
#                                    arxiv_affiliation  \
# 0                                                NaN
# 1                                                NaN
# 2  Department of Biomedical Engineering, Technion...
# 3                                                NaN
#
#                                        arxiv_comment  \
# 0                                7 pages, 10 figures
# 1  v2: 14 pages including supplementary text. Pre...
# 2  7 pages, added code download reference and DOI...
# 3                                                NaN
#
#                        arxiv_doi                        arxiv_journal_ref  \
# 0     10.1103/PhysRevA.82.063823           Phys. Rev. A 82, 063823 (2010)
# 1  10.1093/bioinformatics/btw109  Bioinformatics 2016; 32 (15): 2394-2395
# 2        10.1364/OPTICA.5.000458                  Optica 5 (2018) 458-464
# 3                            NaN                                      NaN
#
# ...

# %%
tree['feed']
# Out:
# {'links': [{'href': 'http://arxiv.org/api/query?search_query%3Dti%3A%22single%20molecule%20microscopy%22%26id_list%3D%26start%3D0%26max_results%3D10',
#    'rel': 'self',
#    'type': 'application/atom+xml'}],
#  'title': 'ArXiv Query: search_query=ti:"single molecule microscopy"&id_list=&start=0&max_results=10',
#  'title_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'http://export.arxiv.org/api/query?search_query=ti:%22single+molecule+microscopy%22&start=0&max_results=10',
#   'value': 'ArXiv Query: search_query=ti:"single molecule microscopy"&id_list=&start=0&max_results=10'},
#  'id': 'http://arxiv.org/api/6AEcvY2vThjES1La0YL13e3y/Xo',
#  'guidislink': True,
#  'link': 'http://arxiv.org/api/6AEcvY2vThjES1La0YL13e3y/Xo',
#  'updated': '2019-09-12T00:00:00-04:00',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=12, tm_hour=4, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=255, tm_isdst=0),
#  'opensearch_totalresults': '4',
# ...

# %%
for col in df_out:
    if "detail" in df_out[col]:
        del df_out[col]

for col in df_out.columns:
    if "detail" in col:
        del df_out[col]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-5130e97e1e7d> in <module>
# ----> 1 for col in df_out:
#       2     if "detail" in df_out[col]:
#       3         del df_out[col]
#       4
#       5 for col in df_out.columns:
#
# NameError: name 'df_out' is not defined

# %%
pubmed = PubMed(tool="PubMedSearh_YHL", email="abc@email.com") #any email adress should be fine
